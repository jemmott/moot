# %% [markdown]
# # Audio Processing
#
# Colin Jemmott for MOOT, July 2024
#
# ## Goal
#
# Take in distance readings, map to smooth theremin sounds.
#
# ## Code Plan
#
# 1. <s>Mock distance</s>
# 2. Exponential smoothing
# 3. Translate distance to frequency (log, low = far)
# 4. Handling none with amplitude
# 5. Play the sound to test
#
# Later
#
# - Active, passive, and boot modes
#     - Active mode start means reset phase
# - video playback speed
# - Add in background audio, by mode, with looping and random start location

# %% [markdown]
# # Mock distance sensor

# %%
class MockDistanceSensor:
    def __init__(self, values):
        self.values = values
        self.index = 0

    @property
    def distance(self):
        if self.index < len(self.values):
            value = self.values[self.index]
            self.index += 1
            return value
        else:
            # Reset the index or handle the empty list as you need
            self.index = 0  # Reset to start
            return self.values[self.index]
        
# Example list of distances the sensor might return
distance_values = [10, 120, 100, 230, 800, None, None, None, None, 100, 120]
distance_readings = []
for d in distance_values:
    distance_readings.extend([d]*50)

# Create a mock sensor
mock_sensor = MockDistanceSensor(distance_readings)

# %% [markdown]
# # Actual code

# %%
import numpy as np
import params

# %%
def map_distance_to_frequency(distance):
    # Clamp the distance within the specified bounds
    clamped_distance = np.clip(distance, params.MIN_DISTANCE, params.MAX_DISTANCE)

    # Map the clamped distance using a logarithmic scale
    log_scale = np.log(clamped_distance)

    # Normalize the logarithmic value between 0 and 1
    normalized_log = (log_scale - np.log(params.MIN_DISTANCE)) / (np.log(params.MAX_DISTANCE) - np.log(params.MIN_DISTANCE))

    # Calculate the frequency
    frequency = params.MAX_FREQ - normalized_log * (params.MAX_FREQ - params.MIN_FREQ)

    return frequency


def smooth_distance(previous_distance, next_distance):
    # exponential smoothing
    if next_distance is None:
        return previous_distance
    else:
        return params.DISTANCE_ALPHA*next_distance + (1 - params.DISTANCE_ALPHA)*previous_distance
    
    
def update_amplitude(previous_amplitude, next_distance):
    if next_distance is None:
        next_amplitude = (1 - params.AMPLITUDE_DECAY) * previous_amplitude
    else:
        next_amplitude = (1 + params.AMPLITUDE_ATTACK) * previous_amplitude
    return np.min([1.0, next_amplitude])
    


# this generates one theremin sample at a time, given the previous phase and current frequency
class PLLSineGenerator:
    def __init__(self):
        self.phase = 0

    def generate_sine_wave(self, freq):
        # Calculate phase increment
        phase_increment = 2 * np.pi * freq / params.SAMPLING_RAT
        
        # Update phase
        self.phase += phase_increment

        # Keep the phase within the range of 0 to 2π to avoid overflow
        self.phase %= 2 * np.pi

        # Generate sine wave
        return 0.5 * np.sin(self.phase)

# %%
audio_chunk_seconds = params.CHUNK_LENGTH / params.SAMPLING_RATE

# TO DO
# Amplitude
# video playback speed (should this happen here?)
# Testing

class Theremin:
    def __init__(self):       
        self.distance = params.MIN_DISTANCE # should never be null
        
        # Audio parameters initial values
        self.amplitude = 1 
        
        # State parameters, initial values
        self.boot_delay_timer = 0 # seconds
        self.boot_sequence_timer = 0 # seconds
        self.shutdown_delay_timer = 0 # seconds
        self.shutdown_sequence_timer = 0 # seconds

    def update(self, past_mode, new_distance):
        """
        past_mode: string, one of "standby", "active", "boot", "shutdown"
        new_distance: distnace in cm, or None
        
        This function generates the next_mode, freq, and amplitude
        """
        
        if new_distance is None:
            self.shutdown_delay_timer += audio_chunk_seconds
            self.boot_delay_timer = 0
        else:
            self.shutdown_delay_timer = 0
            self.boot_delay_timer += audio_chunk_seconds
            
        self.amplitude = update_amplitude(self.amplitude, new_distance)
        self.distance = smooth_distance(self.distance, new_distance)
        
        if past_mode == "standby":
            if new_distance is None:
                Theremin.__init__
                next_mode = "standby"
            else:
                if self.boot_delay_timer > params.BOOT_DELAY_TIME:
                    # initialize
                    self.boot_delay_timer = 0
                    self.boot_sequence_timer = 0 
                    PLLSineGenerator.__init__
                    next_mode = "boot"
                else:
                    next_mode = "standby"
        elif past_mode == "boot":
            self.boot_sequence_timer += audio_chunk_seconds
            if self.boot_sequence_timer > params.BOOT_SEQUENCE_TIME:
                next_mode = "active"
                self.boot_sequence_timer = 0
            else:
                next_mode = "boot"
        elif past_mode == "active":
            if self.shutdown_delay_timer > params.SHUTDOWN_DELAY_TIME:
                self.shutdown_delay_timer = 0
                self.shutdown_sequence_timer = 0
                next_mode = "shutdown"
            else:
                next_mode = "active"
        elif past_mode == "shutdown":
            self.shutdown_sequence_timer += audio_chunk_seconds
            if self.shutdown_sequence_timer > params.SHUTDOWN_SEQUENCE_TIME:
                next_mode = "standby"
                Theremin.__init__
            elif self.boot_delay_timer > params.BOOT_DELAY_TIME:
                next_mode = "active"
            else:
                next_mode = "shutdown"
                
        freq = map_distance_to_frequency(self.distance)
                
        return next_mode, freq, self.amplitude, self.distance

# %%
theremin = Theremin()
mock_sensor = MockDistanceSensor(distance_readings)

mode = "standby" # start mode
for _ in range(len(distance_readings)):
    d = mock_sensor.distance
    mode,f,a,dist = theremin.update(mode,d)
    print(f"input dist: {d} mode: {mode} smooth dist: {dist:.0f} freq: {f:.0f} amplitude: {a:.2f}")
# Out:
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: standby smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 10 mode: boot smooth dist: 10 freq: 1000 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 109 freq: 507 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 119 freq: 489 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 488 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 102 freq: 521 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 1.00
# input dist: 230 mode: boot smooth dist: 217 freq: 365 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 229 freq: 354 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 230 mode: active smooth dist: 230 freq: 353 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 743 freq: 111 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 794 freq: 98 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 799 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: 800 mode: active smooth dist: 800 freq: 96 amplitude: 1.00
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.90
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.81
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.73
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.66
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.59
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.53
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.48
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.43
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.39
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.35
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.31
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.28
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.25
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.23
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.21
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.19
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.17
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.15
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.14
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.12
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.11
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.10
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.09
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.08
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.07
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.06
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.06
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.05
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.05
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.04
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.04
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.03
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.03
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.03
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.03
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.02
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.02
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.02
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.02
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.01
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.01
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.01
# input dist: None mode: active smooth dist: 800 freq: 96 amplitude: 0.01
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.01
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.01
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.01
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.01
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.01
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.01
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.01
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: shutdown smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: None mode: standby smooth dist: 800 freq: 96 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 170 freq: 416 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 107 freq: 511 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 101 freq: 524 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: standby smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.00
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.01
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.01
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.01
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.02
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.03
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.04
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.06
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.09
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.13
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.20
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.30
# input dist: 100 mode: boot smooth dist: 100 freq: 525 amplitude: 0.45
# input dist: 120 mode: boot smooth dist: 118 freq: 491 amplitude: 0.67
# input dist: 120 mode: boot smooth dist: 120 freq: 488 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00
# input dist: 120 mode: boot smooth dist: 120 freq: 487 amplitude: 1.00

# %%
import pyaudio

# Initialize PyAudio
p = pyaudio.PyAudio()
pa_stream = p.open(
    format=pyaudio.paFloat32, channels=1, rate=params.SAMPLING_RATE, output=True
)

pll = PLLSineGenerator()

def generate_sine_wave(freq):
    FRAME_LENGTH, SAMPLE_RATE

while True:

    # audio out
    waveform = generate_sine_wave(freq)
    pa_stream.write(waveform.astype(np.float32).tobytes())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 14
#       9 freq = 440
#      11 while True:
#      12
#      13     # audio out
# ---> 14     waveform = generate_sine_wave(freq, FRAME_LENGTH, SAMPLE_RATE)
#      15     pa_stream.write(waveform.astype(np.float32).tobytes())
#
# NameError: name 'generate_sine_wave' is not defined
